# %%
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func, select, Table, MetaData

# %%
engine = create_engine("postgresql://project_3_333t_user:3LuhMTGZ77yugy4ExOkIqqROOtWMs4rE@dpg-cnbuglv79t8c73ep52q0-a.ohio-postgres.render.com/project_3_333t", echo=False)
Base = automap_base()
Base.prepare(autoload_with=engine)
#School_Location_2 = Base.classes.School_Location_2
session=Session(engine)
#data= session.query(School_Location_2.City).all()

# %%
Base.classes.keys()
# Out:
# ['School_Location_2', 'School_Location', 'School_Info_2']

# %%
schools_table = Base.classes.School_Location
school_info = Base.classes.School_Info_2

# %%
session.commit()

# %%
results = session.query(schools_table.City, schools_table.School_Number).all()

# %%
print(results)
# Out:
# []

# %%
results2 = session.query(school_info.School_Number, school_info.School_Name).all()

# %%
print(results2)
# Out:
# [('902344', 'Algoma Education Connection Secondary School'), ('019186', 'Anna McCrea Public School'), ('043362', 'Ben R McMullin Public School'), ('054542', 'Blind River Public School'), ('490822', 'Boreal French Immersion Public School'), ('137967', 'Central Algoma Intermediate School'), ('285552', 'Central Algoma Public School'), ('891347', 'Central Algoma Secondary School'), ('093548', 'Central Avenue Public School'), ('900869', 'Chapleau High School'), ('101214', 'Chapleau Public School'), ('161276', 'East View Public School'), ('165042', 'Echo Bay Central Public School'), ('293055', 'Elliot Lake Intermediate School'), ('908010', 'Elliot Lake Secondary School'), ('186783', 'Esten Park Public School'), ('202614', 'Francis H Clergue Public School'), ('227331', 'Grand View Public School'), ('230561', 'Greenwood Public School'), ('237191', 'H M Robbins Public School'), ('917370', 'Hornepayne High School'), ('264750', 'Hornepayne Public School'), ('278270', 'Isabel Fletcher Public School'), ('302350', 'Kiwedin Public School'), ('920533', 'Korah Collegiate and Vocational School'), ('018309', 'Korah Intermediate School'), ('926086', 'Michipicoten High School'), ('195200', 'Mountain View Public School'), ('891150', 'North Shore Adolescent Education School'), ('410870', 'Northern Heights Public School'), ('434922', 'Parkland Public School'), ('442054', 'Pinewood Public School'), ('462616', 'Queen Elizabeth Public School'), ('468339', 'R M Moore Public School'), ('485497', 'River View Public School'), ('515396', 'Sir James Dunn Public School'), ('530603', 'St Joseph Island Central Public School'), ('958050', 'Superior Heights Collegiate and Vocational School'), ('672610', 'Superior Heights Community Education'), ('106913', 'Superior Heights Intermediate School'), ('548413', 'Tarentorus Public School'), ('551660', 'Thessalon Public School'), ('895270', 'W C Eaket Secondary School'), ('953148', 'White Pines Collegiate and Vocational School'), ('144872', 'White Pines Intermediate School'), ('765031', "Archbishop O'Sullivan Catholic School"), ('827681', 'Cathedrale Catholic School'), ('708011', 'Georges Vanier Catholic School'), ('715298', 'Holy Cross Catholic Secondary School'), ('717703', 'Holy Name Catholic School'), ('865257', 'Holy Name of Mary Catholic School'), ('903728', 'Delhi District Secondary School'), ('719919', 'Holy Rosary Catholic School'), ('735523', "J J O'Neill Catholic School"), ('728420', 'Loyola Community Learning Centre'), ('835099', 'Nicholson Catholic College'), ('690932', 'Nicholson Catholic College (Grade 7 & 8)'), ('742279', 'Our Lady of Fatima Catholic School'), ('746568', 'Our Lady of Lourdes Catholic School'), ('746690', 'Our Lady of Mercy Catholic School'), ('706264', 'Our Lady of Mount Carmel Catholic School'), ('752932', 'Regiopolis/Notre-Dame Catholic High School'), ('756830', 'Sacred Heart Catholic School'), ('764370', 'Sacred Heart Catholic School'), ('868370', 'Sacred Heart Catholic School'), ('781142', 'St Carthagh Catholic School'), ('756642', 'St Francis of Assisi Catholic School'), ('796220', 'St Gregory Catholic School'), ('799556', 'St James Major'), ('815330', 'St Joseph Catholic School'), ('830984', 'St Marguerite Bourgeoys Catholic School'), ('823570', 'St Martha Catholic School'), ('824330', 'St Martin of Tours Catholic School'), ('831840', 'St Mary Catholic School'), ('865125', 'St Mary Catholic School'), ('834688', 'St Michael Catholic School'), ('764248', 'St Patrick Catholic School'), ('841773', 'St Patrick Catholic School'), ('706744', 'St Paul Catholic Elementary School'), ('842761', 'St Paul Catholic School'), ('841358', 'St Paul Catholic Secondary School'), ('845493', 'St Peter Catholic School'), ('851752', 'St Theresa Catholic Secondary School'), ('856150', 'St Thomas More Catholic School'), ('834301', 'St. Genevieve Catholic School/Ecole Catholique Sainte-Genevieve'), ('724068', 'St. John XXIII Catholic School'), ('773875', 'St. Teresa of Calcutta Catholic School'), ('019313', 'A ...

# %%
sesssion.close()
